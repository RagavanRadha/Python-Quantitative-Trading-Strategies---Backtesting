# %% [markdown]
# # Simple Moving Average Cross Over Strategy

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
class backtest_cross_over:
    
    #object attributes and methods
    def __init__(self,ticker,start,end,sma,mma,lma):
        self.ticker = ticker
        self.start = start
        self.end = end
        self.sma = sma
        self.mma = mma
        self.lma = lma
        
        self.fetch_data()
        self.indicators()
        self.signals()
        self.positions()
        self.returns()
    
    #To fetch the data from yahoo finance
    def fetch_data(self):
        self.df = yf.download(self.ticker,self.start,self.end)
     
    # To compute the indicators necessary for the Strategy
    def indicators(self):
        self.df['sma'] = self.df['Adj Close'].rolling(window=self.sma,center=False).mean()
        self.df['mma'] = self.df['Adj Close'].rolling(window=self.mma,center=False).mean()
        self.df['lma'] = self.df['Adj Close'].rolling(window=self.lma,center=False).mean()
        
    # To generate the trading signals    
    def signals(self):
        self.df['signal'] = np.where((self.df['Adj Close'] > self.df['sma']) & (self.df['Adj Close'] > self.df['mma']) & (self.df['Adj Close'] > self.df['lma']),1,0)
        self.df['signal'] = np.where((self.df['Adj Close'] < self.df['sma']) & (self.df['Adj Close'] > self.df['lma']),0,self.df['signal'])

        self.df['signal'] = np.where((self.df['Adj Close'] < self.df['sma']) & (self.df['Adj Close'] < self.df['mma']) & (self.df['Adj Close'] < self.df['lma']),-1,self.df['signal'])
        self.df['signal'] = np.where((self.df['Adj Close'] > self.df['sma']) & (self.df['Adj Close'] < self.df['lma']),0,self.df['signal'])
    
    #To generate the positions
    def positions(self):
        self.df['positions'] = self.df['signal'].shift(1)
    
    # To generate the Buy & Hold and Strategy returns
    def returns(self):
        self.df['BnH returns'] = self.df['Adj Close'].pct_change()
        self.df['Strategy Returns'] = self.df['BnH returns']*self.df['positions']
        BnH = (self.df['BnH returns']+1).cumprod()[-1]
        Strat_returns = (self.df['Strategy Returns']+1).cumprod()[-1]
        print('Total Strategy Returns:',(self.df['Strategy Returns']+1).cumprod()[-1])
        return Strat_returns

# %%
end = pd.datetime.now().date()
start = end-pd.Timedelta(days=3*252)

# %%
#To generate the returns and validate by optimising the moving average parameters across different indices

sma_list = range(10,30,5)
mma_list = range(30,75,10)
lma_list = range(80,160,10)
indice_list=['^NSEI','SPY','HSI','^CNXIT','^NSEBANK','^HSI','^GSPC']

index_name =[]
sma=[]
mma=[]
lma=[]

net_returns=[]

for i in lma_list:
    for j in mma_list:
        for k in sma_list:
            for l in indice_list:
                print('For',i,j,k,l)
                a = backtest_cross_over(l, start1, end1, i, j, k)
                lma.append(i)
                mma.append(j)
                sma.append(k)
                index_name.append(l)
                net_returns.append(a.returns())
# Out:
# For 80 30 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1433735799457738
# Total Strategy Returns: 1.1433735799457738
# For 80 30 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1224581526219601
# Total Strategy Returns: 1.1224581526219601
# For 80 30 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9360660239600372
# Total Strategy Returns: 0.9360660239600372
# For 80 30 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8086484712482715
# Total Strategy Returns: 1.8086484712482715
# For 80 30 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1640972106174208
# Total Strategy Returns: 1.1640972106174208
# For 80 30 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8572560713690278
# Total Strategy Returns: 0.8572560713690278
# For 80 30 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1193935724434498
# Total Strategy Returns: 1.1193935724434498
# For 80 30 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0749843347884522
# Total Strategy Returns: 1.0749843347884522
# For 80 30 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.131500616933568
# Total Strategy Returns: 1.131500616933568
# For 80 30 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9124639738970588
# Total Strategy Returns: 0.9124639738970588
# For 80 30 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7920438316335403
# Total Strategy Returns: 1.7920438316335403
# For 80 30 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0571073780813303
# Total Strategy Returns: 1.0571073780813303
# For 80 30 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8406190070127149
# Total Strategy Returns: 0.8406190070127149
# For 80 30 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1306897957809063
# Total Strategy Returns: 1.1306897957809063
# For 80 30 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.164469255348787
# Total Strategy Returns: 1.164469255348787
# For 80 30 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1990297507857448
# Total Strategy Returns: 1.1990297507857448
# For 80 30 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9175091119562582
# Total Strategy Returns: 0.9175091119562582
# For 80 30 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7723134372042046
# Total Strategy Returns: 1.7723134372042046
# For 80 30 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.18867037502627
# Total Strategy Returns: 1.18867037502627
# For 80 30 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8538338422283761
# Total Strategy Returns: 0.8538338422283761
# For 80 30 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1919748200959235
# Total Strategy Returns: 1.1919748200959235
# For 80 30 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2214806138210816
# Total Strategy Returns: 1.2214806138210816
# For 80 30 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0980110446751212
# Total Strategy Returns: 1.0980110446751212
# For 80 30 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.895429807737744
# Total Strategy Returns: 0.895429807737744
# For 80 30 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7970315869385096
# Total Strategy Returns: 1.7970315869385096
# For 80 30 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1799197168843654
# Total Strategy Returns: 1.1799197168843654
# For 80 30 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8367938731731357
# Total Strategy Returns: 0.8367938731731357
# For 80 30 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.116822421815583
# Total Strategy Returns: 1.116822421815583
# For 80 40 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.221192997490601
# Total Strategy Returns: 1.221192997490601
# For 80 40 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1374199208337765
# Total Strategy Returns: 1.1374199208337765
# For 80 40 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9349416279463271
# Total Strategy Returns: 0.9349416279463271
# For 80 40 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7640405023263077
# Total Strategy Returns: 1.7640405023263077
# For 80 40 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3102471202978703
# Total Strategy Returns: 1.3102471202978703
# For 80 40 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8010091769839425
# Total Strategy Returns: 0.8010091769839425
# For 80 40 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1480693003691873
# Total Strategy Returns: 1.1480693003691873
# For 80 40 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1481490958694422
# Total Strategy Returns: 1.1481490958694422
# For 80 40 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1465839013292733
# Total Strategy Returns: 1.1465839013292733
# For 80 40 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9113679285021369
# Total Strategy Returns: 0.9113679285021369
# For 80 40 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7071157984918988
# Total Strategy Returns: 1.7071157984918988
# For 80 40 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1460904965213965
# Total Strategy Returns: 1.1460904965213965
# For 80 40 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.7807102206857526
# Total Strategy Returns: 0.7807102206857526
# For 80 40 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1608736644064845
# Total Strategy Returns: 1.1608736644064845
# For 80 40 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2596467342143847
# Total Strategy Returns: 1.2596467342143847
# For 80 40 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1943262507550783
# Total Strategy Returns: 1.1943262507550783
# For 80 40 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9363014668651045
# Total Strategy Returns: 0.9363014668651045
# For 80 40 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7181599468576219
# Total Strategy Returns: 1.7181599468576219
# For 80 40 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2586385560097937
# Total Strategy Returns: 1.2586385560097937
# For 80 40 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8140008904457529
# Total Strategy Returns: 0.8140008904457529
# For 80 40 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.204109358846464
# Total Strategy Returns: 1.204109358846464
# For 80 40 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.326199595674866
# Total Strategy Returns: 1.326199595674866
# For 80 40 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0937045456497407
# Total Strategy Returns: 1.0937045456497407
# For 80 40 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.902460044048636
# Total Strategy Returns: 0.902460044048636
# For 80 40 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7586575751149858
# Total Strategy Returns: 1.7586575751149858
# For 80 40 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2535140971808216
# Total Strategy Returns: 1.2535140971808216
# For 80 40 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.81716018017361
# Total Strategy Returns: 0.81716018017361
# For 80 40 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1281918943300298
# Total Strategy Returns: 1.1281918943300298
# For 80 50 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1640905626388722
# Total Strategy Returns: 1.1640905626388722
# For 80 50 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0773543516158848
# Total Strategy Returns: 1.0773543516158848
# For 80 50 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8988550632082669
# Total Strategy Returns: 0.8988550632082669
# For 80 50 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7831038144278748
# Total Strategy Returns: 1.7831038144278748
# For 80 50 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3645406297787244
# Total Strategy Returns: 1.3645406297787244
# For 80 50 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.7713045909900561
# Total Strategy Returns: 0.7713045909900561
# For 80 50 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0774844629200222
# Total Strategy Returns: 1.0774844629200222
# For 80 50 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.074502099881601
# Total Strategy Returns: 1.074502099881601
# For 80 50 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.147660473975468
# Total Strategy Returns: 1.147660473975468
# For 80 50 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8974585881122447
# Total Strategy Returns: 0.8974585881122447
# For 80 50 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.740332773070347
# Total Strategy Returns: 1.740332773070347
# For 80 50 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2017869342717373
# Total Strategy Returns: 1.2017869342717373
# For 80 50 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.7638792213530219
# Total Strategy Returns: 0.7638792213530219
# For 80 50 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1558407685633978
# Total Strategy Returns: 1.1558407685633978
# For 80 50 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1986289574555509
# Total Strategy Returns: 1.1986289574555509
# For 80 50 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2019946504542447
# Total Strategy Returns: 1.2019946504542447
# For 80 50 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.939278722681978
# Total Strategy Returns: 0.939278722681978
# For 80 50 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7515918179274694
# Total Strategy Returns: 1.7515918179274694
# For 80 50 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3198044798157655
# Total Strategy Returns: 1.3198044798157655
# For 80 50 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8235404307594462
# Total Strategy Returns: 0.8235404307594462
# For 80 50 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1988890173290598
# Total Strategy Returns: 1.1988890173290598
# For 80 50 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2834092180561454
# Total Strategy Returns: 1.2834092180561454
# For 80 50 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0937049155183745
# Total Strategy Returns: 1.0937049155183745
# For 80 50 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9212019459018541
# Total Strategy Returns: 0.9212019459018541
# For 80 50 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7911833824664107
# Total Strategy Returns: 1.7911833824664107
# For 80 50 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2894961584872842
# Total Strategy Returns: 1.2894961584872842
# For 80 50 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.832631210530358
# Total Strategy Returns: 0.832631210530358
# For 80 50 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1281918943300298
# Total Strategy Returns: 1.1281918943300298
# For 80 60 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1442075302094772
# Total Strategy Returns: 1.1442075302094772
# For 80 60 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1105457714757725
# Total Strategy Returns: 1.1105457714757725
# For 80 60 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9348336289498264
# Total Strategy Returns: 0.9348336289498264
# For 80 60 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8434045700171917
# Total Strategy Returns: 1.8434045700171917
# For 80 60 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3645406297787244
# Total Strategy Returns: 1.3645406297787244
# For 80 60 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8120755124877927
# Total Strategy Returns: 0.8120755124877927
# For 80 60 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1048884746867091
# Total Strategy Returns: 1.1048884746867091
# For 80 60 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0404785230126352
# Total Strategy Returns: 1.0404785230126352
# For 80 60 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1973530198966569
# Total Strategy Returns: 1.1973530198966569
# For 80 60 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8949746044035282
# Total Strategy Returns: 0.8949746044035282
# For 80 60 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8146279530197649
# Total Strategy Returns: 1.8146279530197649
# For 80 60 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2017869342717373
# Total Strategy Returns: 1.2017869342717373
# For 80 60 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.7681482550128457
# Total Strategy Returns: 0.7681482550128457
# For 80 60 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1960506045930477
# Total Strategy Returns: 1.1960506045930477
# For 80 60 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1606749651126294
# Total Strategy Returns: 1.1606749651126294
# For 80 60 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2446026616831547
# Total Strategy Returns: 1.2446026616831547
# For 80 60 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9265471839273279
# Total Strategy Returns: 0.9265471839273279
# For 80 60 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7824089922818247
# Total Strategy Returns: 1.7824089922818247
# For 80 60 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3198044798157655
# Total Strategy Returns: 1.3198044798157655
# For 80 60 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8118196641628778
# Total Strategy Returns: 0.8118196641628778
# For 80 60 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2416679315236165
# Total Strategy Returns: 1.2416679315236165
# For 80 60 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.242770700746886
# Total Strategy Returns: 1.242770700746886
# For 80 60 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0937044086488075
# Total Strategy Returns: 1.0937044086488075
# For 80 60 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9068979820100402
# Total Strategy Returns: 0.9068979820100402
# For 80 60 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8242984646415532
# Total Strategy Returns: 1.8242984646415532
# For 80 60 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2894961584872842
# Total Strategy Returns: 1.2894961584872842
# For 80 60 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8171055240495196
# Total Strategy Returns: 0.8171055240495196
# For 80 60 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1281918943300298
# Total Strategy Returns: 1.1281918943300298
# For 80 70 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1568709312520118
# Total Strategy Returns: 1.1568709312520118
# For 80 70 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0790316793854595
# Total Strategy Returns: 1.0790316793854595
# For 80 70 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9083202403445766
# Total Strategy Returns: 0.9083202403445766
# For 80 70 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8813274100966928
# Total Strategy Returns: 1.8813274100966928
# For 80 70 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2731243137248962
# Total Strategy Returns: 1.2731243137248962
# For 80 70 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.7890438223200453
# Total Strategy Returns: 0.7890438223200453
# For 80 70 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0941296909935745
# Total Strategy Returns: 1.0941296909935745
# For 80 70 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0299861832993051
# Total Strategy Returns: 1.0299861832993051
# For 80 70 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1775855778271191
# Total Strategy Returns: 1.1775855778271191
# For 80 70 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8611071861884408
# Total Strategy Returns: 0.8611071861884408
# For 80 70 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8146279530197649
# Total Strategy Returns: 1.8146279530197649
# For 80 70 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1425907986300106
# Total Strategy Returns: 1.1425907986300106
# For 80 70 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.7390802542051612
# Total Strategy Returns: 0.7390802542051612
# For 80 70 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1776243263569686
# Total Strategy Returns: 1.1776243263569686
# For 80 70 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1489705466538438
# Total Strategy Returns: 1.1489705466538438
# For 80 70 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2240556130635136
# Total Strategy Returns: 1.2240556130635136
# For 80 70 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8912293951623329
# Total Strategy Returns: 0.8912293951623329
# For 80 70 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7824089922818247
# Total Strategy Returns: 1.7824089922818247
# For 80 70 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.329098074592574
# Total Strategy Returns: 1.329098074592574
# For 80 70 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.7761401067184739
# Total Strategy Returns: 0.7761401067184739
# For 80 70 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2225388757000524
# Total Strategy Returns: 1.2225388757000524
# For 80 70 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2302384167164053
# Total Strategy Returns: 1.2302384167164053
# For 80 70 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0806157423222698
# Total Strategy Returns: 1.0806157423222698
# For 80 70 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8835656284727361
# Total Strategy Returns: 0.8835656284727361
# For 80 70 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8242984646415532
# Total Strategy Returns: 1.8242984646415532
# For 80 70 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2985763328210618
# Total Strategy Returns: 1.2985763328210618
# For 80 70 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.7941081891238086
# Total Strategy Returns: 0.7941081891238086
# For 80 70 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1151896827819017
# Total Strategy Returns: 1.1151896827819017
# For 90 30 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1530964510211346
# Total Strategy Returns: 1.1530964510211346
# For 90 30 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1321935555125555
# Total Strategy Returns: 1.1321935555125555
# For 90 30 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9924049260713173
# Total Strategy Returns: 0.9924049260713173
# For 90 30 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8309286034086685
# Total Strategy Returns: 1.8309286034086685
# For 90 30 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.140275415227093
# Total Strategy Returns: 1.140275415227093
# For 90 30 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9260963278370886
# Total Strategy Returns: 0.9260963278370886
# For 90 30 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.132156177769638
# Total Strategy Returns: 1.132156177769638
# For 90 30 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0833607649869177
# Total Strategy Returns: 1.0833607649869177
# For 90 30 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.141314439599853
# Total Strategy Returns: 1.141314439599853
# For 90 30 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9717891126443734
# Total Strategy Returns: 0.9717891126443734
# For 90 30 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8479256226327285
# Total Strategy Returns: 1.8479256226327285
# For 90 30 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0068550152459943
# Total Strategy Returns: 1.0068550152459943
# For 90 30 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8970756481142846
# Total Strategy Returns: 0.8970756481142846
# For 90 30 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.143581193377911
# Total Strategy Returns: 1.143581193377911
# For 90 30 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1595786283094156
# Total Strategy Returns: 1.1595786283094156
# For 90 30 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2094293521682924
# Total Strategy Returns: 1.2094293521682924
# For 90 30 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9704167069839789
# Total Strategy Returns: 0.9704167069839789
# For 90 30 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.82757996993885
# Total Strategy Returns: 1.82757996993885
# For 90 30 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1321638211832223
# Total Strategy Returns: 1.1321638211832223
# For 90 30 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9235168502935198
# Total Strategy Returns: 0.9235168502935198
# For 90 30 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1973442671281542
# Total Strategy Returns: 1.1973442671281542
# For 90 30 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2150020177693952
# Total Strategy Returns: 1.2150020177693952
# For 90 30 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.107534123470767
# Total Strategy Returns: 1.107534123470767
# For 90 30 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9327896526009399
# Total Strategy Returns: 0.9327896526009399
# For 90 30 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.853068912470157
# Total Strategy Returns: 1.853068912470157
# For 90 30 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1238291484531235
# Total Strategy Returns: 1.1238291484531235
# For 90 30 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9145104367682789
# Total Strategy Returns: 0.9145104367682789
# For 90 30 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1218533324835338
# Total Strategy Returns: 1.1218533324835338
# For 90 40 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2521542420227272
# Total Strategy Returns: 1.2521542420227272
# For 90 40 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1472859368478647
# Total Strategy Returns: 1.1472859368478647
# For 90 40 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.002490979604013
# Total Strategy Returns: 1.002490979604013
# For 90 40 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7857711239218892
# Total Strategy Returns: 1.7857711239218892
# For 90 40 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2319173657871554
# Total Strategy Returns: 1.2319173657871554
# For 90 40 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9230285326149532
# Total Strategy Returns: 0.9230285326149532
# For 90 40 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1611588478960155
# Total Strategy Returns: 1.1611588478960155
# For 90 40 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.176427848960997
# Total Strategy Returns: 1.176427848960997
# For 90 40 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1565287994502986
# Total Strategy Returns: 1.1565287994502986
# For 90 40 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.981665642632413
# Total Strategy Returns: 0.981665642632413
# For 90 40 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7603492554971216
# Total Strategy Returns: 1.7603492554971216
# For 90 40 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0477908369755093
# Total Strategy Returns: 1.0477908369755093
# For 90 40 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8941039870629925
# Total Strategy Returns: 0.8941039870629925
# For 90 40 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1741091990540928
# Total Strategy Returns: 1.1741091990540928
# For 90 40 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.266267017109613
# Total Strategy Returns: 1.266267017109613
# For 90 40 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2046856496652638
# Total Strategy Returns: 1.2046856496652638
# For 90 40 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9792757614798294
# Total Strategy Returns: 0.9792757614798294
# For 90 40 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7717377965500323
# Total Strategy Returns: 1.7717377965500323
# For 90 40 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.17819433764367
# Total Strategy Returns: 1.17819433764367
# For 90 40 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9064383480329503
# Total Strategy Returns: 0.9064383480329503
# For 90 40 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2095334679084488
# Total Strategy Returns: 1.2095334679084488
# For 90 40 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3316916162970145
# Total Strategy Returns: 1.3316916162970145
# For 90 40 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1031914984170683
# Total Strategy Returns: 1.1031914984170683
# For 90 40 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9296545042659705
# Total Strategy Returns: 0.9296545042659705
# For 90 40 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8134982733819085
# Total Strategy Returns: 1.8134982733819085
# For 90 40 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1854772063254406
# Total Strategy Returns: 1.1854772063254406
# For 90 40 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8870016274072052
# Total Strategy Returns: 0.8870016274072052
# For 90 40 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1332740206607792
# Total Strategy Returns: 1.1332740206607792
# For 90 50 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1969996549439166
# Total Strategy Returns: 1.1969996549439166
# For 90 50 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1270746106810998
# Total Strategy Returns: 1.1270746106810998
# For 90 50 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9637971675483177
# Total Strategy Returns: 0.9637971675483177
# For 90 50 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8535554486345789
# Total Strategy Returns: 1.8535554486345789
# For 90 50 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2829650774308872
# Total Strategy Returns: 1.2829650774308872
# For 90 50 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8941348241824661
# Total Strategy Returns: 0.8941348241824661
# For 90 50 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1310869025531318
# Total Strategy Returns: 1.1310869025531318
# For 90 50 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1260416433585154
# Total Strategy Returns: 1.1260416433585154
# For 90 50 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1576146321979668
# Total Strategy Returns: 1.1576146321979668
# For 90 50 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9559544659112863
# Total Strategy Returns: 0.9559544659112863
# For 90 50 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7617713471235597
# Total Strategy Returns: 1.7617713471235597
# For 90 50 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0987102166441438
# Total Strategy Returns: 1.0987102166441438
# For 90 50 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8800803458132394
# Total Strategy Returns: 0.8800803458132394
# For 90 50 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1690189213706277
# Total Strategy Returns: 1.1690189213706277
# For 90 50 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.186628291635748
# Total Strategy Returns: 1.186628291635748
# For 90 50 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2124195850711816
# Total Strategy Returns: 1.2124195850711816
# For 90 50 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9714863985601186
# Total Strategy Returns: 0.9714863985601186
# For 90 50 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7731690883671798
# Total Strategy Returns: 1.7731690883671798
# For 90 50 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2354509223405588
# Total Strategy Returns: 1.2354509223405588
# For 90 50 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9225667004032503
# Total Strategy Returns: 0.9225667004032503
# For 90 50 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2042896105022904
# Total Strategy Returns: 1.2042896105022904
# For 90 50 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2691511044702577
# Total Strategy Returns: 1.2691511044702577
# For 90 50 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1031900387881832
# Total Strategy Returns: 1.1031900387881832
# For 90 50 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9384289139328381
# Total Strategy Returns: 0.9384289139328381
# For 90 50 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8132483680726594
# Total Strategy Returns: 1.8132483680726594
# For 90 50 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.219506271982819
# Total Strategy Returns: 1.219506271982819
# For 90 50 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8997595844856485
# Total Strategy Returns: 0.8997595844856485
# For 90 50 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1332740206607792
# Total Strategy Returns: 1.1332740206607792
# For 90 60 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.176554524881804
# Total Strategy Returns: 1.176554524881804
# For 90 60 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1758765109614888
# Total Strategy Returns: 1.1758765109614888
# For 90 60 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0023751777009187
# Total Strategy Returns: 1.0023751777009187
# For 90 60 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.9162387277431618
# Total Strategy Returns: 1.9162387277431618
# For 90 60 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2878947532039124
# Total Strategy Returns: 1.2878947532039124
# For 90 60 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9413985137170285
# Total Strategy Returns: 0.9413985137170285
# For 90 60 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1754309704817474
# Total Strategy Returns: 1.1754309704817474
# For 90 60 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0903860923691855
# Total Strategy Returns: 1.0903860923691855
# For 90 60 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2077388960522657
# Total Strategy Returns: 1.2077388960522657
# For 90 60 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9640078311900123
# Total Strategy Returns: 0.9640078311900123
# For 90 60 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8369817444048442
# Total Strategy Returns: 1.8369817444048442
# For 90 60 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1029319099948385
# Total Strategy Returns: 1.1029319099948385
# For 90 60 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.884998783852398
# Total Strategy Returns: 0.884998783852398
# For 90 60 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2148501075881366
# Total Strategy Returns: 1.2148501075881366
# For 90 60 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1490542944329407
# Total Strategy Returns: 1.1490542944329407
# For 90 60 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2553982795484566
# Total Strategy Returns: 1.2553982795484566
# For 90 60 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9690737771941874
# Total Strategy Returns: 0.9690737771941874
# For 90 60 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8043658891267484
# Total Strategy Returns: 1.8043658891267484
# For 90 60 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2401980293255905
# Total Strategy Returns: 1.2401980293255905
# For 90 60 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9094365752007482
# Total Strategy Returns: 0.9094365752007482
# For 90 60 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.247261229366436
# Total Strategy Returns: 1.247261229366436
# For 90 60 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2289640632666718
# Total Strategy Returns: 1.2289640632666718
# For 90 60 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1031905814121798
# Total Strategy Returns: 1.1031905814121798
# For 90 60 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.934226173718463
# Total Strategy Returns: 0.934226173718463
# For 90 60 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8467713838065316
# Total Strategy Returns: 1.8467713838065316
# For 90 60 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2241921131095987
# Total Strategy Returns: 1.2241921131095987
# For 90 60 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8829821864729597
# Total Strategy Returns: 0.8829821864729597
# For 90 60 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1332740206607792
# Total Strategy Returns: 1.1332740206607792
# For 90 70 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1895759230142389
# Total Strategy Returns: 1.1895759230142389
# For 90 70 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1425090708030559
# Total Strategy Returns: 1.1425090708030559
# For 90 70 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9739462019007054
# Total Strategy Returns: 0.9739462019007054
# For 90 70 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.9556599248088027
# Total Strategy Returns: 1.9556599248088027
# For 90 70 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2016132667947794
# Total Strategy Returns: 1.2016132667947794
# For 90 70 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9146990275745567
# Total Strategy Returns: 0.9146990275745567
# For 90 70 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1639852835664146
# Total Strategy Returns: 1.1639852835664146
# For 90 70 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.079390477325924
# Total Strategy Returns: 1.079390477325924
# For 90 70 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1877992670612134
# Total Strategy Returns: 1.1877992670612134
# For 90 70 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9275280738640583
# Total Strategy Returns: 0.9275280738640583
# For 90 70 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8369817444048442
# Total Strategy Returns: 1.8369817444048442
# For 90 70 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0486050529740394
# Total Strategy Returns: 1.0486050529740394
# For 90 70 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.8515089657138522
# Total Strategy Returns: 0.8515089657138522
# For 90 70 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1961342054251465
# Total Strategy Returns: 1.1961342054251465
# For 90 70 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1374670605404593
# Total Strategy Returns: 1.1374670605404593
# For 90 70 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2346727597299376
# Total Strategy Returns: 1.2346727597299376
# For 90 70 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9321349752050971
# Total Strategy Returns: 0.9321349752050971
# For 90 70 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.8043658891267484
# Total Strategy Returns: 1.8043658891267484
# For 90 70 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2489310637286521
# Total Strategy Returns: 1.2489310637286521
# For 90 70 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.869466744511347
# Total Strategy Returns: 0.869466744511347
# For 90 70 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2280460035581608
# Total Strategy Returns: 1.2280460035581608
# For 90 70 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2165710074158576
# Total Strategy Returns: 1.2165710074158576
# For 90 70 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0899885978765647
# Total Strategy Returns: 1.0899885978765647
# For 90 70 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 0.9101907300396835
# Total Strategy Returns: 0.9101907300396835
# For 90 70 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# ...
# Total Strategy Returns: 1.2138883365758113
# Total Strategy Returns: 1.2138883365758113
# For 150 40 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.355647867958594
# Total Strategy Returns: 1.355647867958594
# For 150 40 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1434488436636114
# Total Strategy Returns: 1.1434488436636114
# For 150 40 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0790748678433477
# Total Strategy Returns: 1.0790748678433477
# For 150 40 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.5025490442094485
# Total Strategy Returns: 1.5025490442094485
# For 150 40 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.306396601736743
# Total Strategy Returns: 1.306396601736743
# For 150 40 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0127606952262305
# Total Strategy Returns: 1.0127606952262305
# For 150 40 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1223417706981342
# Total Strategy Returns: 1.1223417706981342
# For 150 50 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1913224315616222
# Total Strategy Returns: 1.1913224315616222
# For 150 50 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1672812399264332
# Total Strategy Returns: 1.1672812399264332
# For 150 50 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0964596056005227
# Total Strategy Returns: 1.0964596056005227
# For 150 50 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.628717504154019
# Total Strategy Returns: 1.628717504154019
# For 150 50 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.33506895915057
# Total Strategy Returns: 1.33506895915057
# For 150 50 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0258666431020202
# Total Strategy Returns: 1.0258666431020202
# For 150 50 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1540383005079224
# Total Strategy Returns: 1.1540383005079224
# For 150 50 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1689808763215284
# Total Strategy Returns: 1.1689808763215284
# For 150 50 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2098915395158067
# Total Strategy Returns: 1.2098915395158067
# For 150 50 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0906333618874833
# Total Strategy Returns: 1.0906333618874833
# For 150 50 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.5273930089188676
# Total Strategy Returns: 1.5273930089188676
# For 150 50 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.238778991896264
# Total Strategy Returns: 1.238778991896264
# For 150 50 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0109392683211365
# Total Strategy Returns: 1.0109392683211365
# For 150 50 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2023841853333999
# Total Strategy Returns: 1.2023841853333999
# For 150 50 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2087080490593878
# Total Strategy Returns: 1.2087080490593878
# For 150 50 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.238270281141375
# Total Strategy Returns: 1.238270281141375
# For 150 50 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1228940252952264
# Total Strategy Returns: 1.1228940252952264
# For 150 50 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.5286140776692996
# Total Strategy Returns: 1.5286140776692996
# For 150 50 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.4114443688272347
# Total Strategy Returns: 1.4114443688272347
# For 150 50 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0458473495543816
# Total Strategy Returns: 1.0458473495543816
# For 150 50 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.20862559890638
# Total Strategy Returns: 1.20862559890638
# For 150 50 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.243233735442203
# Total Strategy Returns: 1.243233735442203
# For 150 50 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1434490688385024
# Total Strategy Returns: 1.1434490688385024
# For 150 50 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0626332190618566
# Total Strategy Returns: 1.0626332190618566
# For 150 50 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.5023419886036824
# Total Strategy Returns: 1.5023419886036824
# For 150 50 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.367847400025704
# Total Strategy Returns: 1.367847400025704
# For 150 50 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0132896883593465
# Total Strategy Returns: 1.0132896883593465
# For 150 50 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1223417706981342
# Total Strategy Returns: 1.1223417706981342
# For 150 60 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2092650491780166
# Total Strategy Returns: 1.2092650491780166
# For 150 60 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2178238993610009
# Total Strategy Returns: 1.2178238993610009
# For 150 60 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1412896327926074
# Total Strategy Returns: 1.1412896327926074
# For 150 60 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7035529958827602
# Total Strategy Returns: 1.7035529958827602
# For 150 60 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.314521267254083
# Total Strategy Returns: 1.314521267254083
# For 150 60 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0435684253138848
# Total Strategy Returns: 1.0435684253138848
# For 150 60 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1992821740550699
# Total Strategy Returns: 1.1992821740550699
# For 150 60 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1689808763215284
# Total Strategy Returns: 1.1689808763215284
# For 150 60 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2622788974128454
# Total Strategy Returns: 1.2622788974128454
# For 150 60 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1444896790606045
# Total Strategy Returns: 1.1444896790606045
# For 150 60 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.6198123107623439
# Total Strategy Returns: 1.6198123107623439
# For 150 60 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2197132733213087
# Total Strategy Returns: 1.2197132733213087
# For 150 60 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0360638446722268
# Total Strategy Returns: 1.0360638446722268
# For 150 60 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2495234509993405
# Total Strategy Returns: 1.2495234509993405
# For 150 60 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2087080490593878
# Total Strategy Returns: 1.2087080490593878
# For 150 60 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2821644344293268
# Total Strategy Returns: 1.2821644344293268
# For 150 60 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1655975744515241
# Total Strategy Returns: 1.1655975744515241
# For 150 60 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.5695489614583984
# Total Strategy Returns: 1.5695489614583984
# For 150 60 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3897212032776847
# Total Strategy Returns: 1.3897212032776847
# For 150 60 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0625061705684316
# Total Strategy Returns: 1.0625061705684316
# For 150 60 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2517519350739663
# Total Strategy Returns: 1.2517519350739663
# For 150 60 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.243233735442203
# Total Strategy Returns: 1.243233735442203
# For 150 60 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.143449247578303
# Total Strategy Returns: 1.143449247578303
# For 150 60 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1057912140686041
# Total Strategy Returns: 1.1057912140686041
# For 150 60 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.5301170220786329
# Total Strategy Returns: 1.5301170220786329
# For 150 60 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3467952238482122
# Total Strategy Returns: 1.3467952238482122
# For 150 60 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0248200249171897
# Total Strategy Returns: 1.0248200249171897
# For 150 60 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1223417706981342
# Total Strategy Returns: 1.1223417706981342
# For 150 70 10 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2226484677276719
# Total Strategy Returns: 1.2226484677276719
# For 150 70 10 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2178238644348218
# Total Strategy Returns: 1.2178238644348218
# For 150 70 10 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1013303939054537
# Total Strategy Returns: 1.1013303939054537
# For 150 70 10 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.7385987850060982
# Total Strategy Returns: 1.7385987850060982
# For 150 70 10 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2771891210295137
# Total Strategy Returns: 1.2771891210295137
# For 150 70 10 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0417792891545843
# Total Strategy Returns: 1.0417792891545843
# For 150 70 10 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1992821740550699
# Total Strategy Returns: 1.1992821740550699
# For 150 70 15 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1571926998224709
# Total Strategy Returns: 1.1571926998224709
# For 150 70 15 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2622787135445535
# Total Strategy Returns: 1.2622787135445535
# For 150 70 15 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0936427287111985
# Total Strategy Returns: 1.0936427287111985
# For 150 70 15 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.6198123107623439
# Total Strategy Returns: 1.6198123107623439
# For 150 70 15 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.248893534301796
# Total Strategy Returns: 1.248893534301796
# For 150 70 15 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0241961747815027
# Total Strategy Returns: 1.0241961747815027
# For 150 70 15 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2495234509993405
# Total Strategy Returns: 1.2495234509993405
# For 150 70 20 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1965192578595012
# Total Strategy Returns: 1.1965192578595012
# For 150 70 20 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2821643394589712
# Total Strategy Returns: 1.2821643394589712
# For 150 70 20 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.109249945108269
# Total Strategy Returns: 1.109249945108269
# For 150 70 20 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.5695489614583984
# Total Strategy Returns: 1.5695489614583984
# For 150 70 20 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.4229687117608334
# Total Strategy Returns: 1.4229687117608334
# For 150 70 20 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0471835852555866
# Total Strategy Returns: 1.0471835852555866
# For 150 70 20 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2517519350739663
# Total Strategy Returns: 1.2517519350739663
# For 150 70 25 ^NSEI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.2306967821011936
# Total Strategy Returns: 1.2306967821011936
# For 150 70 25 SPY
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1434491574850836
# Total Strategy Returns: 1.1434491574850836
# For 150 70 25 HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0658898620984385
# Total Strategy Returns: 1.0658898620984385
# For 150 70 25 ^CNXIT
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.5301170220786329
# Total Strategy Returns: 1.5301170220786329
# For 150 70 25 ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.3790157768082942
# Total Strategy Returns: 1.3790157768082942
# For 150 70 25 ^HSI
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.0193876062732457
# Total Strategy Returns: 1.0193876062732457
# For 150 70 25 ^GSPC
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.1223417706981342
# Total Strategy Returns: 1.1223417706981342

# %%
#Convert the results into the dataframe
results = pd.DataFrame({'long_ma':lma,'med_ma': mma,'short_ma':sma,'index' :index_name,'net_returns':net_returns})

# %%
#To identify the optimum parameters generating greater returns
results.sort_values(by='net_returns',ascending=False,inplace=True)

# %%
results.head()
# Out:
#      long_ma  med_ma  short_ma   index  net_returns
# 675      120      70        10  ^CNXIT     2.047775
# 647      120      60        10  ^CNXIT     2.006497
# 395      100      70        10  ^CNXIT     2.002727
# 815      130      70        10  ^CNXIT     2.002650
# 535      110      70        10  ^CNXIT     1.973770

# %% [markdown]
# As per the above table, CNXIT generates good and consistent returns with the moving average of 10,70,120

# %% [markdown]
# # Exponential Moving Average Cross Over

# %%
class backtest_EMA_cross_over(backtest_cross_over):
    
    def indicators(self):
        self.df['sma'] = self.df['Adj Close'].ewm(span=self.sma,adjust=False).mean()
        self.df['mma'] = self.df['Adj Close'].ewm(span=self.mma,adjust=False).mean()
        self.df['lma'] = self.df['Adj Close'].ewm(span=self.lma,adjust=False).mean()

# %% [markdown]
# Lets try CNXIT with exponential moving average of same parameters to check the returns are higher

# %%
IT_Nifty_EMA_Cross_over = backtest_EMA_cross_over('^CNXIT',start1,end1,10,70,120)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 1.9867302576361112

# %%
IT_Nifty_SMA_Cross_over = backtest_cross_over('^CNXIT',start1,end1,10,70,120)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Total Strategy Returns: 2.047774689258993
